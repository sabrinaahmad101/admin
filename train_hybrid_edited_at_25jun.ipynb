# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings; warnings.simplefilter('ignore')
from scipy import stats
from ast import literal_eval
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.metrics.pairwise import linear_kernel, cosine_similarity
from nltk.stem.snowball import SnowballStemmer
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.corpus import wordnet
from surprise import Reader, Dataset, SVD
from surprise.model_selection.validation import cross_validate
from sklearn.model_selection import train_test_split
from collections import defaultdict
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import accuracy_score
from math import sqrt
import csv

# %%
############ Popularity based #########################

# %%
def popularity(meta,ratings):
    avg = ratings.groupby('book_id')[['rating']].mean()
    count_rating = ratings.groupby('book_id')[['rating']].count()

    avg[avg['rating'].notnull()]['rating'] = avg[avg['rating'].notnull()]['rating'].astype('float')
    vote_averages= avg[avg['rating'].notnull()]['rating'] 
    C = vote_averages.mean()

    count_rating[count_rating['rating'].notnull()]['rating'] = count_rating[count_rating['rating'].notnull()]['rating'].astype('float')
    vote_counts = count_rating[count_rating['rating'].notnull()]['rating']
    m = vote_counts.quantile(0.9)

    meta['ratings_count'] = count_rating['rating']
    meta['average_rating'] = avg['rating']

    content = meta[(meta['ratings_count'].notnull())][['book_id','title', 'authors', 'ratings_count', 'average_rating']]

    content['ratings_count'] = content['ratings_count'].astype('float')

    content['average_rating'] = content['average_rating'].astype('float')

    content.shape
    #print("v rating_count : " + str(ratings_count) + "R average_rating : " + str(average_rating)+"m" + str(m)+"C" + str(C))
    def weighted_rating(x):
        v = x['ratings_count']
        R = x['average_rating']
        return (v/(v+m) * R) + (m/(m+v) * C)

    content['popularity_rating'] = content.apply(weighted_rating, axis=1)
    p = content[['book_id','popularity_rating']]
    print(p)
    #print(pop.shape)
    print("popularity _done")
    return p

# %%
######################### COllaborative ##############################

# %%
def collaborative(ratings,user_id):

    reader = Reader()
    #ratings.head()

    new_ratings = ratings
    data = Dataset.load_from_df(new_ratings[['user_id', 'book_id', 'rating']], reader)
    #data.split(n_folds=2)

    ## Training the data ##
    svd = SVD()
    cross_validate(svd, data, measures=['RMSE', 'MAE'],cv=2)

    trainset = data.build_full_trainset()

    algo = SVD()
    algo.fit(trainset)

    #svd.train(trainset)
    ## Testing the data ##
    testset = trainset.build_anti_testset()
    predictions = algo.test(testset)
    count = 0
     
    for uid, iid, true_r, est, _ in predictions:
        if uid == user_id:
            count = count+1
            new_ratings.loc[len(new_ratings)+1]= [uid,iid,est]
            #print("book_sim " + str(new_ratings))

    cb = new_ratings[(new_ratings['user_id'] == user_id)][['book_id', 'rating']]
    cb.columns=['book_id', 'collab_rating']
    print(cb)
    print("Collab_done")
    return(cb)

# %%
################## content based #########################

# %%
def content_based(meta,ratings,user_id):       
    meta['book_id'] = meta['book_id'].astype('int')
    meta['authors'] = meta['authors'].str.replace(' ','')
    meta['authors'] = meta['authors'].str.lower()
    meta['authors'] = meta['authors'].str.replace(',',' ')
    ratings['book_id'] = ratings['book_id'].astype('int')
    ratings['user_id'] = ratings['user_id'].astype('int')
    ratings['rating'] = ratings['rating'].astype('int')


    #print(md.head())

    meta['authors'] = meta['authors'].apply(lambda x: [x,x])
    #print(md['authors'])
    meta['Genres']=meta['Genres'].str.split(';')
    #print(md['Genres'])

    meta['keywords'] = meta['authors'] + meta['Genres']
    #print(md['keywords'])
    meta['keywords'] = meta['keywords'].str.join(' ')

    tfidf = TfidfVectorizer(stop_words='english')

    tfidf_matrix = tfidf.fit_transform(meta['keywords'])
    tfidf_matrix.shape
    #print(tfidf_matrix)


    cosine_sim = cosine_similarity(tfidf_matrix, tfidf_matrix)
    def build_user_profiles():
        
        user_profiles=np.zeros((60001,999))
        #taking only the first 100000 ratings to build user_profile
        for i in range(0,79999):
            u=ratings.iloc[i]['user_id']
            u = round(u)
            b=ratings.iloc[i]['book_id']
            b = round(b)
            user_profiles[u][b-1]=ratings.iloc[i]['rating']
        #print(user_profiles)
        return user_profiles

    user_profiles=build_user_profiles()

    def get_similar_items_to_user_profile(person_id):
            

        user_ratings = np.empty((999,1))
        cnt=0
        
        for i in range(0,998):
            book_sim=cosine_sim[i]
            #print("book_sim " + str(book_sim))
            user_sim=user_profiles[person_id]
            #print("user_sim " + str(user_sim))
            user_ratings[i]=(book_sim.dot(user_sim))/sum(cosine_sim[i])
            #print("user_ratings " + str(user_ratings))
        maxval = max(user_ratings)
        #print(maxval)

        for i in range(0,998):
            user_ratings[i]=((user_ratings[i]*5.0)/(maxval))
            if(user_ratings[i]>3):
                cnt+=1
        #print(cnt)
        return user_ratings

    content_ratings = get_similar_items_to_user_profile(user_id)
    #print(content_ratings)
    #content_ratings = np.nan_to_num(content_ratings,copy = True,nan=0.0,posinf = None,neginf = None)

    book = meta[['book_id']]
    book1 = pd.DataFrame(data=content_ratings[0:,0:])
    frames = [book, book1]


    #content_rating = pd.concat(frames, axis =1,join_axes=[num.index])
    content_rating = pd.concat(frames, axis=1)
    content_rating = content_rating.reindex(book.index)
    content_rating.columns=['book_id', 'content_rating']
    
    
    print(content_rating)
    print("content_done")
    return(content_rating)

# %%
################## Hybrid system #######################

# %%
def hybrid(user_id,ratings):
    meta = pd.read_csv('CustomData/FinalData.csv')
    print(ratings[(ratings['user_id'] == user_id)][['user_id','book_id', 'rating']])
    rat = ratings
    content_rating = content_based(meta,ratings,user_id)
    collaborative_rating = collaborative(ratings,user_id) 
    popularity_rating = popularity(meta,ratings)
    
        
    hyb = meta[['book_id']]
    title = meta[['book_id','title', 'Genres']]

    hyb = hyb.merge(title,on = 'book_id')
    hyb = hyb.merge(collaborative_rating,on = 'book_id')
    hyb = hyb.merge(popularity_rating, on='book_id')
    hyb = hyb.merge(content_rating, on='book_id')

    def weighted_rating(x):
        collab = x['collab_rating']
        pop = x['popularity_rating']
        content = x['content_rating']
        a = 0.4
        res = (1-2*a)*content + a*collab + a*pop
        #res = a*c + a*v + a*R
        res = "{:.4f}".format(res)
        return res

    hyb['hyb_rating'] = hyb.apply(weighted_rating, axis=1)
    hyb = hyb.sort_values('hyb_rating', ascending=False).head(999)
    hyb.columns = ['book_id' , 'title', 'genres', 'collaborative_rating', 'popularity_rating' , 'content_rating', 'hybrid_rating']

    y_true = ratings[(ratings['user_id'] == user_id)][['user_id','book_id', 'rating']]
    y_true = y_true[['user_id','book_id', 'rating']]
    #rating = ratings[(ratings['user_id'] == user_id)][['user_id','book_id', 'rating']]
    y_pred = hyb[['book_id','hybrid_rating']]
    hybrid = hyb[['book_id','hybrid_rating']]
    hybrid['user_id'] = ''
    hybrid['user_id'] = user_id
    

    #y_pred = y_pred[0:100]
    hyb = hyb[0:100]
    print(y_true)
    e = y_pred.merge(y_true,on = 'book_id')
    e = e.iloc[: , 1:]
    #hyb.to_csv("prediction_list.csv")
    p = np.array(e[['hybrid_rating']])
    r = np.array(e[['rating']])
    err = sqrt(mean_squared_error(r, p))
    print(err)

    file = open("all_user_RMSE.txt", "a+")

    print(e)
    file.write(str(err))
    file.write("\n")

    file.close()
#     file = open(prediction_list.csv, 'wb')
#     writer = csv.writer(file)
#     writer.writerows(e)
#     file.close()    
#     print("Done!")
#     with open('prediction_list.csv', 'a+') as csvfile:
#         writer = csv.writer(csvfile)
#         writer.writerow(e)
    e.to_csv(r'C:\Users\sabri\Desktop\final hybrid\our\1.30am recom\prediction_list.csv', header=None, index=None, sep=' ', mode='a+')
#    y_true.to_csv(r'C:\Users\sabri\Desktop\final hybrid\our\1.30am recom\prediction_list.csv', header=None, index=None, sep=' ', mode='a+')

    
    print(hyb)
    return hybrid

# %%
x_train = pd.read_csv('x_train.csv')
y_test = pd.read_csv('x_test.csv')
ratings = pd.read_csv('CustomData/ratings.csv')
ur = x_train[['user_id']]
ur = np.array(ur)
ur = list(np.unique(ur))
print(ur)

for u in ur:
    #print(ur)
    h = hybrid(u,x_train)

#h = hybrid(116,x_train)
# Out:
# [1, 2, 3, 4, 7, 8, 9, 10, 11, 15, 17, 18, 21, 22, 24, 25, 26, 28, 29, 31, 32, 34, 36, 38, 40, 42, 43, 45, 46, 49, 50, 53, 54, 55, 56, 57, 58, 59, 61, 62, 63, 65, 66, 68, 69, 70, 72, 73, 74, 75, 76, 77, 78, 79, 80, 82, 83, 84, 85, 86, 89, 90, 91, 93, 94, 100, 101, 103, 105, 106, 108, 109, 110, 112, 113, 114, 115, 116, 117, 122, 123, 124, 125, 126, 127, 128, 129, 130, 131, 133, 135, 136, 137, 139, 141, 142, 143, 146, 147, 149, 151, 154, 155, 156, 158, 159, 162, 164, 167, 168, 169, 171, 173, 174, 175, 176, 177, 178, 179, 180, 182, 183, 184, 185, 187, 189, 190, 191, 194, 195, 196, 197, 199, 200, 202, 203, 204, 205, 206, 207, 209, 210, 212, 214, 215, 218, 219, 220, 221, 222, 223, 226, 228, 229, 230, 232, 233, 234, 237, 238, 239, 240, 242, 243, 245, 246, 247, 248, 249, 250, 253, 255, 256, 257, 258, 263, 264, 265, 267, 269, 270, 271, 274, 275, 276, 278, 283, 284, 285, 286, 287, 289, 290, 293, 295, 296, 297, 298, 299, 300, 301, 302, 303, 304, 306, 307, 311, 312, 314, 316, 317, 318, 319, 320, 322, 323, 324, 325, 328, 330, 331, 332, 333, 335, 337, 338, 339, 340, 342, 344, 345, 347, 349, 351, 352, 355, 356, 357, 360, 361, 362, 363, 364, 366, 367, 370, 372, 375, 378, 379, 380, 383, 384, 385, 386, 387, 388, 389, 391, 392, 393, 394, 395, 396, 397, 399, 400, 401, 402, 403, 404, 406, 407, 410, 411, 412, 413, 415, 416, 418, 420, 422, 423, 425, 427, 428, 429, 433, 439, 440, 443, 444, 446, 447, 448, 449, 451, 452, 453, 454, 455, 456, 457, 458, 459, 462, 463, 468, 469, 472, 473, 475, 476, 480, 481, 482, 483, 484, 485, 486, 487, 488, 489, 490, 491, 493, 494, 495, 497, 498, 499, 503, 504, 506, 508, 510, 511, 513, 514, 515, 516, 517, 518, 519, 520, 521, 522, 523, 525, 529, 530, 531, 532, 533, 535, 537, 538, 539, 540, 542, 543, 544, 546, 547, 548, 549, 550, 552, 554, 555, 557, 558, 559, 561, 562, 563, 564, 566, 569, 571, 573, 574, 578, 579, 580, 581, 582, 583, 585, 587, 589, 590, 592, 594, 595, 598, 599, 600, 602, 603, 604, 605, 606, 607, 608, 610, 612, 613, 614, 615, 616, 618, 619, 620, 623, 624, 626, 627, 628, 629, 630, 632, 634, 635, 636, 637, 638, 639, 642, 643, 646, 647, 648, 649, 650, 651, 653, 654, 656, 657, 658, 662, 663, 665, 667, 669, 670, 675, 676, 679, 682, 683, 684, 687, 688, 689, 690, 691, 694, 695, 697, 698, 699, 701, 702, 703, 706, 709, 710, 711, 712, 714, 715, 716, 717, 718, 721, 723, 724, 725, 726, 728, 731, 733, 735, 736, 738, 740, 741, 744, 745, 746, 748, 749, 750, 751, 752, 755, 756, 757, 758, 759, 760, 763, 764, 765, 769, 770, 773, 774, 777, 778, 779, 780, 781, 782, 783, 788, 789, 790, 791, 792, 793, 795, 796, 797, 801, 802, 803, 804, 806, 807, 808, 809, 810, 811, 812, 813, 814, 815, 816, 818, 819, 820, 822, 823, 826, 828, 829, 830, 832, 835, 837, 839, 840, 841, 848, 850, 853, 855, 857, 859, 860, 861, 863, 865, 866, 868, 869, 870, 871, 872, 875, 879, 880, 881, 884, 885, 887, 891, 892, 895, 896, 897, 898, 899, 900, 903, 905, 907, 908, 909, 912, 913, 914, 916, 917, 918, 919, 920, 921, 923, 924, 925, 926, 928, 929, 930, 932, 933, 934, 935, 936, 940, 942, 943, 944, 946, 947, 950, 951, 952, 953, 954, 956, 957, 959, 961, 963, 966, 968, 969, 971, 973, 975, 976, 977, 978, 979, 980, 981, 982, 983, 987, 989, 990, 991, 992, 994, 995, 996, 997, 999, 1000, 1002, 1003, 1005, 1006, 1007, 1008, 1009, 1010, 1011, 1012, 1013, 1014, 1016, 1018, 1019, 1020, 1023, 1024, 1025, 1027, 1028, 1029, 1030, 1032, 1033, 1034, 1037, 1038, 1040, 1041, 1042, 1043, 1044, 1046, 1047, 1049, 1050, 1052, 1055, 1057, 1058, 1059, 1060, 1061, 1063, 1065, 1068, 1069, 1070, 1073, 1074, 1076, 1077, 1079, 1081, 1083, 1084, 1086, 1087, 1089, 1091, 1092, 1095, 1096, 1102, 1103, 1104, 1107, 1108, 1109, 1110, 1111, 1112, 1113, 1114, 1115, 1116, 1117, 1118, 1122, 1123, 1124, 1125, 1126, 1127, 1129, 1131, 1132, 1135, 1137, 1138, 1139, 1143, 1144, 1145, 1146, 1147, 1148, 1149, 1150, 1153, 1155, 1157, 1159, 1160, 1161, 1162, 1164, 1166, 1167, 1168, 1172, 1173, 1174, 1175, 1176, 1178, 1179, 1180, 1183, 1184, 1187, 1188, 1189, 1191, 1193, 1195, 1196, 1197, 1198, 1200, 1204, 1205, 12 ...
#        user_id  book_id  rating
# 2449         1      268       3
# 65184        1       47       3
#      book_id  content_rating
# 0          1    9.809109e-02
# 1          2    1.568906e-01
# 2          3    0.000000e+00
# 3          4    9.307448e-02
# 4          5    1.823738e-01
# ..       ...             ...
# 994      995    6.659763e-03
# 995      996    0.000000e+00
# 996      997    1.597555e-02
# 997      998    3.838781e-03
# 998      999   1.251448e-311
#
# [999 rows x 2 columns]
# content_done
#        book_id  collab_rating
# 2449     268.0       3.000000
# 65184     47.0       3.000000
# 80000    335.0       3.906672
# 80001    709.0       4.004936
# 80002    237.0       3.367579
# ...        ...            ...
# 80707    656.0       3.529210
# 80708    889.0       3.545879
# 80709    147.0       3.579430
# 80710     51.0       3.724207
# 80711    615.0       3.852591
#
# [714 rows x 2 columns]
# Collab_done
#      book_id  popularity_rating
# 2          3           3.995876
# 3          4           3.885571
# 4          5           4.226896
# 5          6           3.783131
# 7          8           3.942409
# ..       ...                ...
# 989      990           3.866213
# 994      995           3.901113
# 996      997           3.859289
# 997      998           3.890053
# 998      999           3.912173
#
# [713 rows x 2 columns]
# popularity _done
#        user_id  book_id    rating
# 2449       1.0    268.0  3.000000
# 65184      1.0     47.0  3.000000
# 80000      1.0    335.0  3.906672
# 80001      1.0    709.0  4.004936
# 80002      1.0    237.0  3.367579
# ...        ...      ...       ...
# 80707      1.0    656.0  3.529210
# 80708      1.0    889.0  3.545879
# 80709      1.0    147.0  3.579430
# 80710      1.0     51.0  3.724207
# 80711      1.0    615.0  3.852591
#
# [714 rows x 3 columns]
# 0.6888917555327231
#     hybrid_rating  user_id    rating
# 0          3.9653      1.0  3.615143
# 1          3.4305      1.0  4.333615
# 2          3.3837      1.0  4.265071
# 3          3.3610      1.0  4.378954
# 4          3.3484      1.0  4.357826
# ..            ...      ...       ...
# 499        2.6601      1.0  2.779323
# 500        2.6223      1.0  2.693009
# 501        2.5853      1.0  2.796396
# 502        2.5705      1.0  2.552822
# 503        2.5546      1.0  2.526035
#
# [504 rows x 3 columns]
#      book_id                                              title  \
# 432      820                             The Remains of the Day
# 74       103                          The Count of Monte Cristo
# 13        25  Harry Potter and the Deathly Hallows (Harry Po...
# 73       102                          Where the Wild Things Are
# 262      490  Maus I: A Survivor's Tale: My Father Bleeds Hi...
# ..       ...                                                ...
# 334      598        Assassin's Apprentice (Farseer Trilogy, #1)
# 498      977                     Inferno (The Divine Comedy #1)
# 178      323                  The Unbearable Lightness of Being
# 121      198                                   The Color Purple
# 434      829                                 A Room with a View
#
#                         genres  collaborative_rating  popularity_rating  \
# 432                  [History]              3.615143           3.798008
# 74          [History, Fiction]              4.333615           4.161578
# 13        [Fantasy, Young-Age]              4.265071           4.115632
# 73             [Kids, Fantasy]              4.378954           4.023544
# 262                  [History]              4.357826           3.868274
# ..                         ...                   ...                ...
# 334                  [Fantasy]              4.004037           3.881686
# 498        [Thriller, Fiction]              4.007274           3.873829
# 178       [Fiction, Self-Help]              3.919302           3.942863
# 121  [Drama, History, Fiction]              3.905321           3.881301
# 434                  [Classic]              3.953735           3.925011
#
#      content_rating hybrid_rating
# 432        5.000000        3.9653
# 74         0.162125        3.4305
# 13         0.156891        3.3837
# 73         0.000000        3.3610
# 262        0.289871        3.3484
# ..              ...           ...
# 334        0.000000        3.1543
# 498        0.003646        3.1532
# 178        0.041134        3.1531
# 121        0.189740        3.1526
# 434        0.000000        3.1515
#
# [100 rows x 7 columns]
#        user_id  book_id  rating
# 23124      2.0    301.0     5.0
# 39972      2.0    315.0     3.0
# 65322      2.0     26.0     4.0
# 72360      2.0     33.0     4.0
#      book_id  content_rating
# 0          1    7.105672e-02
# 1          2    0.000000e+00
# 2          3    0.000000e+00
# 3          4    1.765165e-01
# 4          5    1.321107e-01
# ..       ...             ...
# 994      995    4.094557e-03
# 995      996    0.000000e+00
# 996      997    2.359378e-02
# 997      998    2.360160e-03
# 998      999   1.250917e-311
#
# [999 rows x 2 columns]
# content_done
#        book_id  collab_rating
# 23124    301.0       5.000000
# 39972    315.0       3.000000
# 65322     26.0       4.000000
# 72360     33.0       4.000000
# 80712    335.0       4.250408
# ...        ...            ...
# 81417    656.0       4.165290
# 81418    889.0       4.070454
# 81419    147.0       3.982079
# 81420     51.0       4.232311
# 81421    615.0       4.107656
#
# [714 rows x 2 columns]
# Collab_done
#      book_id  popularity_rating
# 2          3           3.992619
# 3          4           3.875343
# 4          5           4.223274
# 5          6           3.779093
# 7          8           3.937365
# ..       ...                ...
# 989      990           3.850453
# 994      995           3.889787
# 996      997           3.845332
# 997      998           3.879014
# 998      999           3.900657
#
# [713 rows x 2 columns]
# popularity _done
#        user_id  book_id    rating
# 23124      2.0    301.0  5.000000
# 39972      2.0    315.0  3.000000
# 65322      2.0     26.0  4.000000
# 72360      2.0     33.0  4.000000
# 80712      2.0    335.0  4.250408
# ...        ...      ...       ...
# 81417      2.0    656.0  4.165290
# 81418      2.0    889.0  4.070454
# 81419      2.0    147.0  3.982079
# 81420      2.0     51.0  4.232311
# 81421      2.0    615.0  4.107656
#
# [714 rows x 3 columns]
# 0.9187123468866709
#     hybrid_rating  user_id    rating
# 0          4.5361      2.0  5.000000
# 1          4.0081      2.0  4.000000
# 2          3.5658      2.0  4.701695
# 3          3.5475      2.0  4.000000
# 4          3.4821      2.0  4.687766
# ..            ...      ...       ...
# 499        2.8207      2.0  3.160511
# 500        2.8050      2.0  3.000000
# 501        2.7944      2.0  3.114720
# 502        2.7929      2.0  3.120201
# 503        2.7329      2.0  2.976865
#
# [504 rows x 3 columns]
#      book_id                                              title  \
# 169      301                                  Heart of Darkness
# 18        33                                Memoirs of a Geisha
# 74       103                          The Count of Monte Cristo
# 14        26             The Da Vinci Code (Robert Langdon, #2)
# 73       102                          Where the Wild Things Are
# ..       ...                                                ...
# 37        54  The Hitchhiker's Guide to the Galaxy (Hitchhik...
# 359      661  Alexander and the Terrible, Horrible, No Good,...
# 261      489                                        The Prophet
# 158      274                                      The Godfather
# 343      621               Are You There God? It's Me, Margaret
#
#                  genres  collaborative_rating  popularity_rating  \
# 169           [History]              5.000000           3.840128
# 18          [Biography]              4.000000           3.791347
# 74   [History, Fiction]              4.701695           4.153640
# 14    [Thriller, Drama]              4.000000           4.280396
# 73      [Kids, Fantasy]              4.687766           4.017490
# ..                  ...                   ...                ...
# 37   [Fantasy, Fiction]              4.517657           3.722635
# 359              [Kids]              4.710871           3.532228
# 261            [Poetry]              4.338736           3.903445
# 158   [Thriller, Drama]              4.264410           3.896019
# 343  [Drama, Young-Age]              4.301444           3.926917
#
#      content_rating hybrid_rating
# 169        5.000000        4.5361
# 18         4.457638        4.0081
# 74         0.118209        3.5658
# 14         1.176797        3.5475
# 73         0.000000        3.4821
# ..              ...           ...
# 37         0.010336        3.2982
# 359        0.000000        3.2972
# 261        0.000000        3.2969
# 158        0.155860        3.2953
# 343        0.010620        3.2935
#
# [100 rows x 7 columns]
#        user_id  book_id  rating
# 3936       3.0    138.0     2.0
# 4225       3.0     13.0     2.0
# 4498       3.0    522.0     1.0
# 6723       3.0     76.0     1.0
# 7867       3.0    587.0     1.0
# 9489       3.0    117.0     1.0
# 15376      3.0    773.0     2.0
# 19578      3.0    410.0     3.0
# 20908      3.0     55.0     1.0
# 23047      3.0    501.0     1.0
# 24425      3.0     59.0     3.0
# 30188      3.0    905.0     2.0
# 33804      3.0    484.0     1.0
# 34281      3.0    150.0     2.0
# 35507      3.0    177.0     2.0
# 36000      3.0    247.0     3.0
# 36070      3.0    471.0     1.0
# 37127      3.0    599.0     1.0
# 47829      3.0    229.0     2.0
# 48760      3.0    265.0     2.0
# 49806      3.0    883.0     1.0
# 51139      3.0    531.0     2.0
# 54499      3.0     28.0     2.0
# 62116      3.0    101.0     1.0
# 62909      3.0    420.0     1.0
# 64815      3.0    815.0     1.0
# 66091      3.0    715.0     3.0
# 67277      3.0      4.0     3.0
# 70243      3.0    427.0     2.0
# 72295      3.0     77.0     1.0
# 75114      3.0    660.0     1.0
#      book_id  content_rating
# 0          1    2.941575e-01
# 1          2    1.309498e-01
# 2          3    7.489918e-02
# 3          4    2.032179e+00
# 4          5    4.087710e-01
# ..       ...             ...
# 994      995    3.988817e-02
# 995      996    0.000000e+00
# 996      997    5.836746e-02
# 997      998    3.556106e-02
# 998      999   1.250927e-311
#
# [999 rows x 2 columns]
# content_done
#        book_id  collab_rating
# 3936     138.0       2.000000
# 4225      13.0       2.000000
# 4498     522.0       1.000000
# 6723      76.0       1.000000
# 7867     587.0       1.000000
# ...        ...            ...
# 82100    656.0       1.996981
# 82101    889.0       1.844915
# 82102    147.0       1.810006
# 82103     51.0       2.147707
# 82104    615.0       2.000451
#
# [714 rows x 2 columns]
# Collab_done
#      book_id  popularity_rating
# 2          3           3.972967
# 3          4           3.819475
# 4          5           4.204865
# 5          6           3.757667
# 7          8           3.911400
# ..       ...                ...
# 989      990           3.770939
# 994      995           3.814090
# 996      997           3.769850
# 997      998           3.803740
# 998      999           3.823796
#
# [713 rows x 2 columns]
# popularity _done
#        user_id  book_id    rating
# 3936       3.0    138.0  2.000000
# 4225       3.0     13.0  2.000000
# 4498       3.0    522.0  1.000000
# 6723       3.0     76.0  1.000000
# 7867       3.0    587.0  1.000000
# ...        ...      ...       ...
# 82100      3.0    656.0  1.996981
# 82101      3.0    889.0  1.844915
# 82102      3.0    147.0  1.810006
# 82103      3.0     51.0  2.147707
# 82104      3.0    615.0  2.000451
#
# [714 rows x 3 columns]
# 0.4704974674841275
#     hybrid_rating  user_id  rating
# 0          3.7046      3.0     3.0
# 1          3.2548      3.0     3.0
# 2          3.1342      3.0     3.0
# 3          2.8406      3.0     3.0
# 4          2.8175      3.0     3.0
# ..            ...      ...     ...
# 499        1.9174      3.0     1.0
# 500        1.9153      3.0     1.0
# 501        1.9149      3.0     1.0
# 502        1.9087      3.0     1.0
# 503        1.9069      3.0     1.0
#
# [504 rows x 3 columns]
#      book_id                                              title  \
# 143      247  The 7 Habits of Highly Effective People: Power...
# 42        59                                    Charlotte's Web
# 1          4                              To Kill a Mockingbird
# 383      715                                Death of a Salesman
# 219      410        Things Fall Apart (The African Trilogy, #1)
# ..       ...                                                ...
# 183      337      The Ultimate Hitchhiker's Guide to the Galaxy
# 213      402             The Tell-Tale Heart and Other Writings
# 64        85                                    The Giving Tree
# 404      744  The Power of Now: A Guide to Spiritual Enlight...
# 19        36                          The Giver (The Giver, #1)
#
#                   genres  collaborative_rating  popularity_rating  \
# 143          [Self-Help]              3.000000           3.761580
# 42       [Kids, Fiction]              3.000000           3.803863
# 1     [Self-Help, Drama]              3.000000           3.819475
# 383  [Classic, Academic]              3.000000           3.808706
# 219  [Academic, History]              3.000000           3.789189
# ..                   ...                   ...                ...
# 183   [Fantasy, Fiction]              2.265951           3.770604
# 213    [Horror, Fiction]              2.363488           3.697089
# 64                [Kids]              2.289533           3.705883
# 404          [Self-Help]              2.174222           3.839788
# 19             [Fantasy]              2.327851           3.686903
#
#      content_rating hybrid_rating
# 143        5.000000        3.7046
# 42         2.666328        3.2548
# 1          2.032179        3.1342
# 383        0.585421        2.8406
# 219        0.508874        2.8175
# ..              ...           ...
# 183        0.073617        2.4293
# 213        0.024031        2.4290
# 64         0.153737        2.4289
# 404        0.103584        2.4263
# 19         0.098915        2.4257
#
# [100 rows x 7 columns]
#        user_id  book_id  rating
# 136        4.0    117.0     4.0
# 1448       4.0    264.0     3.0
# 1878       4.0     45.0     4.0
# 1983       4.0    373.0     4.0
# 2331       4.0    468.0     4.0
# ...        ...      ...     ...
# 72696      4.0    255.0     2.0
# 75040      4.0    111.0     2.0
# 76505      4.0    436.0     3.0
# 77486      4.0    388.0     4.0
# 78584      4.0     86.0     4.0
#
# [76 rows x 3 columns]
#      book_id  content_rating
# 0          1    3.847702e-01
# 1          2    2.420205e+00
# 2          3    2.740028e-01
# 3          4    7.602649e-01
# 4          5    1.381607e+00
# ..       ...             ...
# 994      995    2.417458e-01
# 995      996    0.000000e+00
# 996      997    2.760850e-01
# 997      998    3.018376e-01
# 998      999   1.251448e-311
#
# [999 rows x 2 columns]
# content_done
#        book_id  collab_rating
# 136      117.0       4.000000
# 1448     264.0       3.000000
# 1878      45.0       4.000000
# 1983     373.0       4.000000
# 2331     468.0       4.000000
# ...        ...            ...
# 82738    656.0       3.992981
# 82739    889.0       3.935185
# 82740    147.0       3.762976
# 82741     51.0       4.070742
# 82742    615.0       4.116861
#
# [714 rows x 2 columns]
# Collab_done
#      book_id  popularity_rating
# 2          3           3.971132
# 3          4           3.813020
# 4          5           4.202961
# 5          6           3.756078
# 7          8           3.908474
# ..       ...                ...
# 989      990           3.763056
# 994      995           3.808689
# 996      997           3.761266
# 997      998           3.798551
# 998      999           3.818319
#
# [713 rows x 2 columns]
# popularity _done
#        user_id  book_id    rating
# 136        4.0    117.0  4.000000
# 1448       4.0    264.0  3.000000
# 1878       4.0     45.0  4.000000
# 1983       4.0    373.0  4.000000
# 2331       4.0    468.0  4.000000
# ...        ...      ...       ...
# 82738      4.0    656.0  3.992981
# 82739      4.0    889.0  3.935185
# 82740      4.0    147.0  3.762976
# 82741      4.0     51.0  4.070742
# 82742      4.0    615.0  4.116861
#
# [714 rows x 3 columns]
# 0.776305080105153
#     hybrid_rating  user_id    rating
# 0          4.5343      4.0  5.000000
# 1          4.0110      4.0  5.000000
# 2          3.9952      4.0  4.689254
# 3          3.9731      4.0  5.000000
# 4          3.9604      4.0  5.000000
# ..            ...      ...       ...
# 499        2.7553      4.0  3.123263
# 500        2.7490      4.0  3.099169
# 501        2.7458      4.0  3.126922
# 502        2.6578      4.0  2.828780
# 503        2.5155      4.0  2.000000
#
# [504 rows x 3 columns]
#      book_id                                              title  \
# 261      489                                        The Prophet
# 12        24  Harry Potter and the Goblet of Fire (Harry Pot...
# 13        25  Harry Potter and the Deathly Hallows (Harry Po...
# 74       103                          The Count of Monte Cristo
# 66        87                       Night (The Night Trilogy #1)
# ..       ...                                                ...
# 120      197            Dead Until Dark (Sookie Stackhouse, #1)
# 396      734              Roots: The Saga of an American Family
# 444      856                     Gathering Blue (The Giver, #2)
# 267      497                                       Black Beauty
# 146      256  Three Cups of Tea: One Man's Mission to Promot...
#
#                           genres  collaborative_rating  popularity_rating  \
# 261                     [Poetry]              5.000000           3.835842
# 12          [Fantasy, Young-Age]              5.000000           3.817475
# 13          [Fantasy, Young-Age]              4.689254           4.088753
# 74            [History, Fiction]              5.000000           4.102998
# 66                   [Biography]              5.000000           3.673844
# ..                           ...                   ...                ...
# 120  [Romance, Fantasy, Fiction]              4.255888           3.845618
# 396           [History, Fiction]              4.433640           3.670472
# 444                  [Young-Age]              3.959627           3.804309
# 267              [Kids, Classic]              4.230459           3.783077
# 146                  [Biography]              4.286355           3.752738
#
#      content_rating hybrid_rating
# 261        5.000000        4.5343
# 12         2.420205        4.0110
# 13         2.420205        3.9952
# 74         1.659651        3.9731
# 66         2.454354        3.9604
# ..              ...           ...
# 120        0.273769        3.2954
# 396        0.263795        3.2944
# 444        0.924646        3.2905
# 267        0.420577        3.2895
# 146        0.368158        3.2893
#
# [100 rows x 7 columns]
#        user_id  book_id  rating
# 121        7.0    481.0     4.0
# 680        7.0    400.0     4.0
# 2891       7.0    219.0     5.0
# 4988       7.0    115.0     4.0
# 9406       7.0    516.0     5.0
# 15415      7.0     28.0     5.0
# 19828      7.0    322.0     5.0
# 21988      7.0     89.0     5.0
# 25685      7.0    205.0     3.0
# 27544      7.0    154.0     3.0
# 28799      7.0    116.0     4.0
# 29193      7.0    255.0     4.0
# 29399      7.0     50.0     5.0
# 30212      7.0    377.0     4.0
# 37134      7.0    492.0     4.0
# 38925      7.0    760.0     5.0
# 39520      7.0     25.0     4.0
# 40900      7.0    405.0     4.0
# 44029      7.0    184.0     5.0
# 44082      7.0    593.0     3.0
# 44894      7.0    725.0     5.0
# 46737      7.0    806.0     3.0
# 46983      7.0    729.0     5.0
# 47767      7.0    956.0     5.0
# 53723      7.0    410.0     3.0
# 56842      7.0    838.0     3.0
# 57090      7.0    936.0     3.0
# 59496      7.0     83.0     4.0
# 59658      7.0    612.0     5.0
# 61876      7.0     48.0     5.0
# 62536      7.0      8.0     2.0
# 64806      7.0    696.0     3.0
# 64963      7.0    238.0     3.0
# 67092      7.0     37.0     4.0
# 69926      7.0    194.0     4.0
# 69961      7.0    126.0     5.0
# 71097      7.0    416.0     5.0
# 71495      7.0    510.0     4.0
# 75688      7.0     79.0     4.0
# 75713      7.0    883.0     4.0
# 77586      7.0    125.0     5.0
# 77711      7.0    953.0     1.0
# 79028      7.0     55.0     5.0
#      book_id  content_rating
# 0          1    6.316013e-01
# 1          2    8.085353e-01
# 2          3    5.029388e-01
# 3          4    1.856983e-01
# 4          5    3.638645e-01
# ..       ...             ...
# 994      995    9.005173e-02
# 995      996    0.000000e+00
# 996      997    1.141055e-01
# 997      998    1.209205e-01
# 998      999   1.251449e-311
#
# [999 rows x 2 columns]
# content_done
#        book_id  collab_rating
# 121      481.0       4.000000
# 680      400.0       4.000000
# 2891     219.0       5.000000
# 4988     115.0       4.000000
# 9406     516.0       5.000000
# ...        ...            ...
# 83409    656.0       3.920022
# 83410    889.0       4.015701
# 83411    147.0       3.651831
# 83412     51.0       3.922807
# 83413    615.0       3.924334
#
# [714 rows x 2 columns]
# Collab_done
#      book_id  popularity_rating
# 2          3           3.969284
# 3          4           3.807163
# 4          5           4.201553
# 5          6           3.754904
# 7          8           3.905587
# ..       ...                ...
# 989      990           3.754774
# 994      995           3.805116
# 996      997           3.753690
# 997      998           3.794535
# 998      999           3.814224
#
# [713 rows x 2 columns]
# popularity _done
#        user_id  book_id    rating
# 121        7.0    481.0  4.000000
# 680        7.0    400.0  4.000000
# 2891       7.0    219.0  5.000000
# 4988       7.0    115.0  4.000000
# 9406       7.0    516.0  5.000000
# ...        ...      ...       ...
# 83409      7.0    656.0  3.920022
# 83410      7.0    889.0  4.015701
# 83411      7.0    147.0  3.651831
# 83412      7.0     51.0  3.922807
# 83413      7.0    615.0  3.924334
#
# [714 rows x 3 columns]
# 0.8566301786255447
#     hybrid_rating  user_id    rating
# 0          3.9869      7.0  4.000000
# 1          3.9442      7.0  5.000000
# 2          3.8441      7.0  5.000000
# 3          3.8359      7.0  5.000000
# 4          3.8001      7.0  5.000000
# ..            ...      ...       ...
# 499        2.7346      7.0  3.092919
# 500        2.6595      7.0  3.052929
# 501        2.6314      7.0  2.733871
# 502        2.5291      7.0  2.000000
# 503        1.9777      7.0  1.000000
#
# [504 rows x 3 columns]
#      book_id                                              title  \
# 58        79                                        The Odyssey
# 16        28                                  Lord of the Flies
# 38        55                                    Brave New World
# 33        50                            Where the Sidewalk Ends
# 31        48                                     Fahrenheit 451
# ..       ...                                                ...
# 223      417                                The Thirteenth Tale
# 37        54  The Hitchhiker's Guide to the Galaxy (Hitchhik...
# 183      337      The Ultimate Hitchhiker's Guide to the Galaxy
# 189      354                                            Beloved
# 406      758         Stiff: The Curious Lives of Human Cadavers
#
#                          genres  collaborative_rating  popularity_rating  \
# 58                     [Poetry]              4.000000           3.467212
# 16   [Psychological, Young-Age]              5.000000           4.121072
# 38           [Fantasy, Fiction]              5.000000           3.942848
# 33               [Poetry, Kids]              5.000000           3.754078
# 31           [Fantasy, Fiction]              5.000000           3.842635
# ..                          ...                   ...                ...
# 223         [Thriller, Fiction]              4.220136           3.918818
# 37           [Fantasy, Fiction]              4.279851           3.652228
# 183          [Fantasy, Fiction]              4.320023           3.757776
# 189          [Fiction, Fantasy]              4.249697           3.818576
# 406                   [History]              4.232901           3.868153
#
#      content_rating hybrid_rating
# 58         5.000000        3.9869
# 16         1.478818        3.9442
# 38         1.334570        3.8441
# 33         1.671330        3.8359
# 31         1.315413        3.8001
# ..              ...           ...
# 223        0.076480        3.2709
# 37         0.478894        3.2686
# 183        0.181080        3.2673
# 189        0.198885        3.2671
# 406        0.126935        3.2658
#
# [100 rows x 7 columns]
#        user_id  book_id  rating
# 1626       8.0    529.0     5.0
# 3497       8.0     97.0     4.0
# 5260       8.0    772.0     4.0
# 5972       8.0    479.0     4.0
# 6863       8.0    493.0     5.0
# 16284      8.0    977.0     5.0
# 19848      8.0     13.0     4.0
# 23127      8.0    718.0     5.0
# 31554      8.0    301.0     4.0
# 34718      8.0    778.0     5.0
# 42996      8.0    651.0     4.0
# 43102      8.0     94.0     4.0
# 45312      8.0    194.0     4.0
# 49273      8.0     83.0     4.0
# 50946      8.0      5.0     3.0
# 56491      8.0     79.0     4.0
# 60770      8.0     71.0     3.0
# 62608      8.0     55.0     5.0
# 62855      8.0    354.0     1.0
# 69839      8.0    560.0     2.0
# 72077      8.0    264.0     3.0
# 76311      8.0     45.0     3.0
#      book_id  content_rating
# 0          1    1.224908e-01
# 1          2    6.309923e-02
# 2          3    1.277188e-01
# 3          4    2.831710e-01
# 4          5    1.384156e+00
# ..       ...             ...
# 994      995    9.414513e-02
# 995      996    0.000000e+00
# 996      997    9.447458e-02
# 997      998    6.622516e-02
# 998      999   1.251481e-311
#
# [999 rows x 2 columns]
# content_done
#        book_id  collab_rating
# 1626     529.0       5.000000
# 3497      97.0       4.000000
# 5260     772.0       4.000000
# 5972     479.0       4.000000
# 6863     493.0       5.000000
# ...        ...            ...
# 84101    656.0       3.852496
# 84102    889.0       3.915928
# 84103    147.0       3.727075
# 84104     51.0       3.807456
# 84105    615.0       3.777634
#
# [714 rows x 2 columns]
# Collab_done
#      book_id  popularity_rating
# 2          3           3.966984
# 3          4           3.800651
# 4          5           4.199632
# 5          6           3.752386
# 7          8           3.903245
# ..       ...                ...
# 989      990           3.746561
# 994      995           3.799586
# 996      997           3.745691
# 997      998           3.789509
# 998      999           3.809869
#
# [713 rows x 2 columns]
# popularity _done
#        user_id  book_id    rating
# 1626       8.0    529.0  5.000000
# 3497       8.0     97.0  4.000000
# 5260       8.0    772.0  4.000000
# 5972       8.0    479.0  4.000000
# 6863       8.0    493.0  5.000000
# ...        ...      ...       ...
# 84101      8.0    656.0  3.852496
# 84102      8.0    889.0  3.915928
# 84103      8.0    147.0  3.727075
# 84104      8.0     51.0  3.807456
# 84105      8.0    615.0  3.777634
#
# [714 rows x 3 columns]
# 0.8393336791616115
#     hybrid_rating  user_id    rating
# 0          3.9852      8.0  4.000000
# 1          3.7984      8.0  5.000000
# 2          3.6396      8.0  5.000000
# 3          3.6012      8.0  5.000000
# 4          3.5860      8.0  5.000000
# ..            ...      ...       ...
# 499        2.7082      8.0  2.994626
# 500        2.6593      8.0  2.883673
# 501        2.6465      8.0  3.062082
# 502        2.4576      8.0  2.000000
# 503        1.9541      8.0  1.000000
#
# [504 rows x 3 columns]
#      book_id                                            title  \
# 58        79                                      The Odyssey
# 38        55                                  Brave New World
# 498      977                   Inferno (The Divine Comedy #1)
# 415      778                      The Hunchback of Notre-Dame
# 292      529                               Gulliver's Travels
# ..       ...                                              ...
# 177      322                                       Neverwhere
# 95       133  Anne of Green Gables (Anne of Green Gables, #1)
# 120      197          Dead Until Dark (Sookie Stackhouse, #1)
# 232      444            Winnie-the-Pooh (Winnie-the-Pooh, #1)
# 207      389                  The Final Empire (Mistborn, #1)
#
#                               genres  collaborative_rating  popularity_rating  \
# 58                          [Poetry]              4.000000           3.463117
# 38                [Fantasy, Fiction]              5.000000           3.938904
# 498              [Thriller, Fiction]              5.000000           3.762765
# 415               [Romance, Fiction]              5.000000           3.695817
# 292  [Kids, Fantasy, Fiction, Drama]              5.000000           3.797281
# ..                               ...                   ...                ...
# 177                        [Fantasy]              4.171361           3.836973
# 95                   [Kids, Classic]              4.257027           3.732500
# 120      [Romance, Fantasy, Fiction]              4.160691           3.838335
# 232                   [Kids, Comedy]              4.235040           3.779229
# 207               [Fantasy, Fiction]              4.246787           3.740667
#
#      content_rating hybrid_rating
# 58         5.000000        3.9852
# 38         1.114138        3.7984
# 498        0.672713        3.6396
# 415        0.614506        3.6012
# 292        0.335280        3.5860
# ..              ...           ...
# 177        0.044023        3.2121
# 95         0.080061        3.2118
# 120        0.055075        3.2106
# 232        0.016347        3.2090
# 207        0.066594        3.2083
#
# [100 rows x 7 columns]
#        user_id  book_id  rating
# 453        9.0    587.0     4.0
# 739        9.0     76.0     4.0
# 1587       9.0     26.0     2.0
# 2174       9.0    258.0     5.0
# 8386       9.0     13.0     5.0
# 9603       9.0     28.0     4.0
# 10603      9.0     78.0     2.0
# 11709      9.0    658.0     4.0
# 13946      9.0     60.0     5.0
# 15034      9.0    150.0     3.0
# 18523      9.0    317.0     4.0
# 19757      9.0    407.0     5.0
# 23029      9.0    916.0     2.0
# 26016      9.0    596.0     2.0
# 26701      9.0    227.0     2.0
# 30727      9.0    476.0     2.0
# 31011      9.0    181.0     5.0
# 32059      9.0    372.0     4.0
# 35779      9.0     75.0     3.0
# 35932      9.0    213.0     2.0
# 35976      9.0    122.0     4.0
# 39387      9.0    119.0     4.0
# 43026      9.0    941.0     5.0
# 45541      9.0     55.0     4.0
# 46034      9.0     14.0     4.0
# 47618      9.0    179.0     4.0
# 49837      9.0    570.0     5.0
# 51400      9.0    397.0     3.0
# 57353      9.0     10.0     5.0
# 63185      9.0    326.0     3.0
# 66628      9.0    959.0     1.0
# 67863      9.0    943.0     5.0
# 69732      9.0    955.0     3.0
# 70558      9.0    344.0     4.0
# 72456      9.0     81.0     1.0
# 73717      9.0    121.0     5.0
# 74067      9.0    115.0     4.0
# 78073      9.0      5.0     5.0
# 78194      9.0    101.0     5.0
# 79748      9.0    815.0     5.0
#      book_id  content_rating
# 0          1    2.720482e-01
# 1          2    1.016975e-01
# 2          3    4.321107e-02
# 3          4    2.150132e-01
# 4          5    1.749083e+00
# ..       ...             ...
# 994      995    1.230949e-01
# 995      996    0.000000e+00
# 996      997    1.069821e-01
# 997      998    7.095363e-02
# 998      999   1.250926e-311
#
# [999 rows x 2 columns]
# content_done
#        book_id  collab_rating
# 453      587.0       4.000000
# 739       76.0       4.000000
# 1587      26.0       2.000000
# 2174     258.0       5.000000
# 8386      13.0       5.000000
# ...        ...            ...
# 84775    656.0       3.650954
# 84776    889.0       3.513307
# 84777    147.0       3.474209
# 84778     51.0       4.084595
# 84779    615.0       3.932160
#
# [714 rows x 2 columns]
# Collab_done
#      book_id  popularity_rating
# 2          3           3.963831
# 3          4           3.791471
# 4          5           4.196865
# 5          6           3.750017
# 7          8           3.899527
# ..       ...                ...
# 989      990           3.733777
# 994      995           3.791335
# 996      997           3.733708
# 997      998           3.782324
# 998      999           3.800729
#
# [713 rows x 2 columns]
# popularity _done
#        user_id  book_id    rating
# 453        9.0    587.0  4.000000
# 739        9.0     76.0  4.000000
# 1587       9.0     26.0  2.000000
# 2174       9.0    258.0  5.000000
# 8386       9.0     13.0  5.000000
# ...        ...      ...       ...
# 84775      9.0    656.0  3.650954
# 84776      9.0    889.0  3.513307
# 84777      9.0    147.0  3.474209
# 84778      9.0     51.0  4.084595
# 84779      9.0    615.0  3.932160
#
# [714 rows x 3 columns]
# 0.7690493628678533
#     hybrid_rating  user_id  rating
# 0          4.2815      9.0     5.0
# 1          4.1137      9.0     4.0
# 2          4.0286      9.0     5.0
# 3          3.7448      9.0     5.0
# 4          3.7316      9.0     5.0
# ..            ...      ...     ...
# 499        2.4278      9.0     2.0
# 500        2.3852      9.0     2.0
# 501        2.3216      9.0     2.0
# 502        2.1505      9.0     1.0
# 503        1.9857      9.0     1.0
#
# [504 rows x 3 columns]
#      book_id                                              title  \
# 72       101                             Me Talk Pretty One Day
# 199      372            Dress Your Family in Corduroy and Denim
# 2          5                                   The Great Gatsby
# 43        60  The Curious Incident of the Dog in the Night-Time
# 148      258  The Shadow of the Wind (The Cemetery of Forgot...
# ..       ...                                                ...
# 274      504                                     Redeeming Love
# 381      709                                       Nine Stories
# 362      664                             Breakfast at Tiffany's
# 248      472                           Man's Search for Meaning
# 301      550  The Omnivore's Dilemma: A Natural History of F...
#
#                    genres  collaborative_rating  popularity_rating  \
# 72            [Biography]              5.000000           3.868804
# 199            [Academic]              4.000000           3.784226
# 2                 [Drama]              5.000000           4.196865
# 43   [Young-Age, Fiction]              5.000000           3.957504
# 148   [Thriller, Fantasy]              5.000000           3.746177
# ..                    ...                   ...                ...
# 274      [Romance, Drama]              4.161459           3.758984
# 381             [Drama, ]              4.256150           3.666807
# 362    [Classic, Fiction]              3.919261           3.848045
# 248  [Self-Help, Fiction]              4.247161           3.716227
# 301            [Academic]              4.041137           3.755436
#
#      content_rating hybrid_rating
# 72         3.669699        4.2815
# 199        5.000000        4.1137
# 2          1.749083        4.0286
# 43         0.809094        3.7448
# 148        1.165716        3.7316
# ..              ...           ...
# 274        0.186385        3.2055
# 381        0.180688        3.2053
# 362        0.468480        3.2006
# 248        0.067983        3.1990
# 301        0.390949        3.1968
#
# [100 rows x 7 columns]
#        user_id  book_id  rating
# 2723      10.0    426.0     1.0
# 3095      10.0    255.0     3.0
# 4366      10.0    103.0     5.0
# 4539      10.0    155.0     5.0
# 8358      10.0     11.0     3.0
# 8537      10.0     45.0     5.0
# 11575     10.0    258.0     5.0
# 19068     10.0    413.0     4.0
# 21500     10.0    217.0     4.0
# 25671     10.0    172.0     2.0
# 26892     10.0     63.0     4.0
# 27276     10.0    476.0     4.0
# 27481     10.0    325.0     4.0
# 28876     10.0    357.0     4.0
# 29987     10.0     40.0     3.0
# 31270     10.0      4.0     5.0
# 36731     10.0     35.0     4.0
# 37378     10.0    653.0     5.0
# 38707     10.0    287.0     4.0
# 38867     10.0    298.0     3.0
# 39192     10.0     26.0     3.0
# 41658     10.0    688.0     2.0
# 41737     10.0      5.0     5.0
# 42003     10.0    704.0     4.0
# 45477     10.0     38.0     5.0
# 48536     10.0    160.0     3.0
# 50871     10.0     25.0     4.0
# 59835     10.0    522.0     5.0
# 63232     10.0    109.0     3.0
# 64830     10.0    212.0     2.0
# 67245     10.0     10.0     5.0
# 69684     10.0    658.0     5.0
# 70565     10.0     83.0     5.0
# 74561     10.0     37.0     3.0
#      book_id  content_rating
# 0          1    3.490215e-01
# 1          2    5.302531e-01
# 2          3    1.980390e-01
# 3          4    1.243316e+00
# 4          5    2.228750e+00
# ..       ...             ...
# 994      995    9.675580e-02
# 995      996    0.000000e+00
# 996      997    1.433846e-01
# 997      998    6.963428e-02
# 998      999   1.251448e-311
#
# [999 rows x 2 columns]
# content_done
#        book_id  collab_rating
# 2723     426.0       1.000000
# 3095     255.0       3.000000
# 4366     103.0       5.000000
# 4539     155.0       5.000000
# 8358      11.0       3.000000
# ...        ...            ...
# 85455    656.0       3.704800
# 85456    889.0       3.781736
# 85457    147.0       3.413724
# 85458     51.0       4.106683
# 85459    615.0       3.986925
#
# [714 rows x 2 columns]
# Collab_done
#      book_id  popularity_rating
# 2          3           3.961183
# 3          4           3.786155
# 4          5           4.194331
# 5          6           3.748384
# 7          8           3.897403
# ..       ...                ...
# 989      990           3.725950
# 994      995           3.786295
# 996      997           3.726824
# 997      998           3.776025
# 998      999           3.795698
#
# [713 rows x 2 columns]
# popularity _done
#        user_id  book_id    rating
# 2723      10.0    426.0  1.000000
# 3095      10.0    255.0  3.000000
# 4366      10.0    103.0  5.000000
# 4539      10.0    155.0  5.000000
# 8358      10.0     11.0  3.000000
# ...        ...      ...       ...
# 85455     10.0    656.0  3.704800
# 85456     10.0    889.0  3.781736
# 85457     10.0    147.0  3.413724
# 85458     10.0     51.0  4.106683
# 85459     10.0    615.0  3.986925
#
# [714 rows x 3 columns]
# 0.7800714379644169
#     hybrid_rating  user_id    rating
# 0          4.1235     10.0  5.000000
# 1          4.0609     10.0  5.000000
# 2          3.7996     10.0  5.000000
# 3          3.7995     10.0  5.000000
# 4          3.7962     10.0  5.000000
# ..            ...      ...       ...
# 499        2.6050     10.0  2.637696
# 500        2.5999     10.0  2.000000
# 501        2.5492     10.0  2.000000
# 502        2.3773     10.0  2.000000
# 503        2.0522     10.0  1.000000
#
# [504 rows x 3 columns]
#      book_id                                              title  \
# 2          5                                   The Great Gatsby
# 74       103                          The Count of Monte Cristo
# 356      653                                          Blindness
# 62        83                               A Tale of Two Cities
# 148      258  The Shadow of the Wind (The Cemetery of Forgot...
# ..       ...                                                ...
# 238      456                           A Streetcar Named Desire
# 72       101                             Me Talk Pretty One Day
# 7         14                                        Animal Farm
# 498      977                     Inferno (The Divine Comedy #1)
# 279      512                     The Complete Stories and Poems
#
#                         genres  collaborative_rating  popularity_rating  \
# 2                      [Drama]              5.000000           4.194331
# 74          [History, Fiction]              5.000000           4.086153
# 356          [Horror, Fiction]              5.000000           3.733175
# 62   [History, Fiction, Drama]              5.000000           3.728552
# 148        [Thriller, Fantasy]              5.000000           3.738604
# ..                         ...                   ...                ...
# 238           [Romance, Drama]              4.109445           3.739439
# 72                 [Biography]              4.179646           3.864653
# 7                      [Drama]              3.825480           3.982881
# 498        [Thriller, Fiction]              4.239184           3.749719
# 279          [Poetry, Fiction]              4.201369           3.740592
#
#      content_rating hybrid_rating
# 2          2.228750        4.1235
# 74         2.132310        4.0609
# 356        1.531681        3.7996
# 62         1.540417        3.7995
# 148        1.503893        3.7962
# ..              ...           ...
# 238        0.400277        3.2196
# 72         0.000000        3.2177
# 7          0.469170        3.2172
# 498        0.102232        3.2160
# 279        0.189654        3.2147
#
# [100 rows x 7 columns]
#        user_id  book_id  rating
# 2388      11.0     26.0     3.0
# 3061      11.0    426.0     4.0
# 15722     11.0    522.0     3.0
# 25697     11.0     47.0     4.0
# 26618     11.0    408.0     3.0
# 28890     11.0     11.0     4.0
# 35508     11.0    325.0     4.0
# 36711     11.0    516.0     4.0
# 40303     11.0    574.0     3.0
# 42832     11.0    495.0     3.0
# 43241     11.0      8.0     5.0
# 44693     11.0    115.0     4.0
# 48409     11.0    378.0     4.0
# 50194     11.0    258.0     3.0
# 50218     11.0    236.0     5.0
# 62330     11.0    688.0     3.0
# 63854     11.0    211.0     3.0
# 68553     11.0    587.0     3.0
#      book_id  content_rating
# 0          1    2.750138e-01
# 1          2    2.200686e-01
# 2          3    4.856360e-02
# 3          4    4.241622e-01
# 4          5    5.113135e-01
# ..       ...             ...
# 994      995    4.363013e-02
# 995      996    0.000000e+00
# 996      997    1.105643e-01
# 997      998    2.514902e-02
# 998      999   1.250918e-311
#
# [999 rows x 2 columns]
# content_done
#        book_id  collab_rating
# 2388      26.0       3.000000
# 3061     426.0       4.000000
# 15722    522.0       3.000000
# 25697     47.0       4.000000
# 26618    408.0       3.000000
# ...        ...            ...
# 86151    656.0       3.410675
# 86152    889.0       3.494860
# 86153    147.0       3.484593
# 86154     51.0       3.540345
# 86155    615.0       3.604904
#
# [714 rows x 2 columns]
# Collab_done
#      book_id  popularity_rating
# 2          3           3.957380
# 3          4           3.778371
# 4          5           4.191548
# 5          6           3.745552
# 7          8           3.893916
# ..       ...                ...
# 989      990           3.713578
# 994      995           3.776965
# 996      997           3.714485
# 997      998           3.766967
# 998      999           3.784935
#
# [713 rows x 2 columns]
# popularity _done
#        user_id  book_id    rating
# 2388      11.0     26.0  3.000000
# 3061      11.0    426.0  4.000000
# 15722     11.0    522.0  3.000000
# 25697     11.0     47.0  4.000000
# 26618     11.0    408.0  3.000000
# ...        ...      ...       ...
# 86151     11.0    656.0  3.410675
# 86152     11.0    889.0  3.494860
# 86153     11.0    147.0  3.484593
# 86154     11.0     51.0  3.540345
# 86155     11.0    615.0  3.604904
#
# [714 rows x 3 columns]
# 0.7017810847077574
#     hybrid_rating  user_id    rating
# 0          3.9172     11.0  3.415580
# 1          3.9154     11.0  5.000000
# 2          3.5658     11.0  4.000000
# 3          3.4255     11.0  4.583523
# 4          3.4183     11.0  3.764940
# ..            ...      ...       ...
# 499        2.6473     11.0  2.861437
# 500        2.6357     11.0  3.034935
# 501        2.6198     11.0  2.804165
# 502        2.5499     11.0  2.681895
# 503        2.5458     11.0  2.628725
#
# [504 rows x 3 columns]
#      book_id                                             title  \
# 61        82                                     Into the Wild
# 3          8                            The Catcher in the Rye
# 6         11                                   The Kite Runner
# 59        80                                 The Little Prince
# 48        67                          A Thousand Splendid Suns
# ..       ...                                               ...
# 285      520                        The Wind-Up Bird Chronicle
# 368      681  Little House in the Big Woods (Little House, #1)
# 87       121                                            Lolita
# 501      997                             The Scarlet Pimpernel
# 4          9             Angels & Demons  (Robert Langdon, #1)
#
#                                   genres  collaborative_rating  \
# ...
#      book_id  content_rating
# 0          1    3.491157e-01
# 1          2    1.510647e-01
# 2          3    5.812497e-02
# 3          4    4.917936e-01
# 4          5    5.748831e-01
# ..       ...             ...
# 994      995    1.164769e-01
# 995      996    0.000000e+00
# 996      997    1.388913e-01
# 997      998    1.203910e-01
# 998      999   1.250918e-311
#
# [999 rows x 2 columns]
# content_done
#        book_id  collab_rating
# 1388     387.0       3.000000
# 3270     132.0       4.000000
# 3530      42.0       5.000000
# 3949     158.0       4.000000
# 5476       8.0       5.000000
# ...        ...            ...
# 94358    656.0       3.744273
# 94359    889.0       3.847551
# 94360    147.0       3.711975
# 94361     51.0       4.065350
# 94362    615.0       4.092151
#
# [714 rows x 2 columns]
# Collab_done
#      book_id  popularity_rating
# 2          3           3.941640
# 3          4           3.742837
# 4          5           4.174176
# 5          6           3.730210
# 7          8           3.871847
# ..       ...                ...
# 989      990           3.664570
# 994      995           3.741911
# 996      997           3.660227
# 997      998           3.726413
# 998      999           3.763920
#
# [713 rows x 2 columns]
# popularity _done
#        user_id  book_id    rating
# 1388      32.0    387.0  3.000000
# 3270      32.0    132.0  4.000000
# 3530      32.0     42.0  5.000000
# 3949      32.0    158.0  4.000000
# 5476      32.0      8.0  5.000000
# ...        ...      ...       ...
# 94358     32.0    656.0  3.744273
# 94359     32.0    889.0  3.847551
# 94360     32.0    147.0  3.711975
# 94361     32.0     51.0  4.065350
# 94362     32.0    615.0  4.092151
#
# [714 rows x 3 columns]
# 0.8874338726189963
#     hybrid_rating  user_id    rating
# 0          4.4775     32.0  5.000000
# 1          4.0283     32.0  5.000000
# 2          3.9161     32.0  4.000000
# 3          3.7830     32.0  4.000000
# 4          3.7727     32.0  4.098372
# ..            ...      ...       ...
# 499        2.7438     32.0  3.137851
# 500        2.7331     32.0  3.000000
# 501        2.6941     32.0  3.008274
# 502        2.6761     32.0  3.027314
# 503        2.6237     32.0  2.844455
#
# [504 rows x 3 columns]
#      book_id                                              title  \
# 301      550  The Omnivore's Dilemma: A Natural History of F...
# 200      373                                            The BFG
# 211      398  Fast Food Nation: The Dark Side of the All-Ame...
# 105      158  Charlie and the Chocolate Factory (Charlie Buc...
# 199      372            Dress Your Family in Corduroy and Denim
# ..       ...                                                ...
# 452      870  Team of Rivals: The Political Genius of Abraha...
# 70        95                         The Picture of Dorian Gray
# 160      276                         Foundation (Foundation #1)
# 194      365                                     V for Vendetta
# 282      515                                The Prince of Tides
#
#                genres  collaborative_rating  popularity_rating  \
# 301        [Academic]              5.000000           3.693760
# 200   [Kids, Fiction]              5.000000           3.791745
# 211        [Academic]              4.000000           3.705338
# 105   [Kids, Classic]              4.000000           3.860719
# 199        [Academic]              4.098372           3.731115
# ..                ...                   ...                ...
# 452       [Biography]              4.507600           3.615181
# 70          [Fiction]              4.229556           3.909552
# 160         [Fiction]              4.440917           3.681059
# 194        [Thriller]              4.322440           3.793736
# 282  [Romance, Drama]              4.327643           3.718345
#
#      content_rating hybrid_rating
# 301        5.000000        4.4775
# 200        2.558014        4.0283
# 211        4.169762        3.9161
# 105        3.193632        3.7830
# 199        3.204636        3.7727
# ..              ...           ...
# 452        0.232395        3.2956
# 70         0.197211        3.2951
# 160        0.223781        3.2935
# 194        0.226600        3.2918
# 282        0.365355        3.2915
#
# [100 rows x 7 columns]
#        user_id  book_id  rating
# 1559      34.0    296.0     5.0
# 4623      34.0    424.0     3.0
# 4682      34.0    520.0     5.0
# 8499      34.0    442.0     5.0
# 8988      34.0    611.0     4.0
# 12274     34.0    958.0     5.0
# 13402     34.0    360.0     4.0
# 15251     34.0    400.0     4.0
# 18425     34.0    126.0     5.0
# 19841     34.0    547.0     4.0
# 20226     34.0    297.0     3.0
# 30068     34.0    937.0     4.0
# 31192     34.0    738.0     5.0
# 31522     34.0    121.0     4.0
# 33324     34.0    653.0     4.0
# 36397     34.0    546.0     2.0
# 38412     34.0     43.0     4.0
# 40177     34.0     70.0     4.0
# 44778     34.0    570.0     3.0
# 46294     34.0    666.0     3.0
# 46759     34.0     65.0     4.0
# 47883     34.0    405.0     4.0
# 48127     34.0     89.0     4.0
# 49251     34.0    162.0     4.0
# 49787     34.0     13.0     5.0
# 51498     34.0    232.0     4.0
# 58624     34.0     60.0     2.0
# 61845     34.0    498.0     5.0
# 67348     34.0     59.0     5.0
# 74028     34.0    168.0     4.0
#      book_id  content_rating
# 0          1    2.507994e-01
# 1          2    3.364463e-01
# 2          3    3.174928e-01
# 3          4    1.051020e-01
# 4          5    8.100657e-02
# ..       ...             ...
# 994      995    1.170366e-01
# 995      996    0.000000e+00
# 996      997    1.094140e-01
# 997      998    1.260047e-01
# 998      999   1.251448e-311
#
# [999 rows x 2 columns]
# content_done
#        book_id  collab_rating
# 1559     296.0       5.000000
# 4623     424.0       3.000000
# 4682     520.0       5.000000
# 8499     442.0       5.000000
# 8988     611.0       4.000000
# ...        ...            ...
# 95042    656.0       3.535742
# 95043    889.0       3.809030
# 95044    147.0       3.727757
# 95045     51.0       3.940638
# 95046    615.0       3.980399
#
# [714 rows x 2 columns]
# Collab_done
#      book_id  popularity_rating
# 2          3           3.940098
# 3          4           3.739480
# 4          5           4.173011
# 5          6           3.729413
# 7          8           3.870071
# ..       ...                ...
# 989      990           3.659415
# 994      995           3.738065
# 996      997           3.654060
# 997      998           3.723263
# 998      999           3.759928
#
# [713 rows x 2 columns]
# popularity _done
#        user_id  book_id    rating
# 1559      34.0    296.0  5.000000
# 4623      34.0    424.0  3.000000
# 4682      34.0    520.0  5.000000
# 8499      34.0    442.0  5.000000
# 8988      34.0    611.0  4.000000
# ...        ...      ...       ...
# 95042     34.0    656.0  3.535742
# 95043     34.0    889.0  3.809030
# 95044     34.0    147.0  3.727757
# 95045     34.0     51.0  3.940638
# 95046     34.0    615.0  3.980399
#
# [714 rows x 3 columns]
# 0.7880247194446678
#     hybrid_rating  user_id    rating
# 0          4.4750     34.0  5.000000
# 1          4.0278     34.0  5.000000
# 2          4.0070     34.0  4.000000
# 3          3.9522     34.0  5.000000
# 4          3.7813     34.0  4.000000
# ..            ...      ...       ...
# 499        2.6223     34.0  2.941462
# 500        2.6168     34.0  2.998713
# 501        2.6103     34.0  2.885266
# 502        2.5668     34.0  2.000000
# 503        2.3757     34.0  2.000000
#
# [504 rows x 3 columns]
#      book_id                                              title  \
# 268      498                                      War and Peace
# 42        59                                    Charlotte's Web
# 46        65                                Slaughterhouse-Five
# 90       126                          Dune (Dune Chronicles #1)
# 107      162                                       The Stranger
# ..       ...                                                ...
# 84       118                                  The Joy Luck Club
# 396      734              Roots: The Saga of an American Family
# 118      187                                Uglies (Uglies, #1)
# 493      964  J.R.R. Tolkien 4-Book Boxed Set: The Hobbit an...
# 21        38                           The Time Traveler's Wife
#
#                                   genres  collaborative_rating  \
# 268                            [History]              5.000000
# 42                       [Kids, Fiction]              5.000000
# 46                             [Fiction]              4.000000
# 90             [SciFi, Fantasy, Classic]              5.000000
# 107                            [Fiction]              4.000000
# ..                                   ...                   ...
# 84                    [Classic, Fiction]              3.773050
# 396                   [History, Fiction]              4.379891
# 118                            [Fantasy]              4.039070
# 493          [Fantasy, Drama, Young-Age]              4.368981
# 21   [Romance, SciFi, Fantasy, Domestic]              3.911743
#
#      popularity_rating  content_rating hybrid_rating
# 268           3.687541        5.000000        4.4750
# 42            3.759689        2.619696        4.0278
# 46            3.774291        4.486470        4.0070
# 90            3.896533        1.967984        3.9522
# 107           3.993394        2.919708        3.7813
# ..                 ...             ...           ...
# 84            3.940641        0.628037        3.2111
# 396           3.593404        0.104543        3.2102
# 118           3.774695        0.420320        3.2096
# 493           3.578698        0.145608        3.2082
# 21            3.893335        0.430458        3.2081
#
# [100 rows x 7 columns]
#        user_id  book_id  rating
# 1827      36.0    323.0     4.0
# 1831      36.0    121.0     4.0
# 3334      36.0    561.0     4.0
# 3688      36.0     22.0     4.0
# 6837      36.0    100.0     3.0
# 10085     36.0    538.0     3.0
# 10698     36.0     50.0     5.0
# 14486     36.0     32.0     4.0
# 15653     36.0    383.0     4.0
# 17005     36.0     54.0     3.0
# 19345     36.0    214.0     3.0
# 20044     36.0    516.0     4.0
# 25092     36.0     28.0     5.0
# 26420     36.0    662.0     4.0
# 28643     36.0    189.0     5.0
# 29824     36.0     45.0     3.0
# 30560     36.0     41.0     4.0
# 30743     36.0    150.0     4.0
# 32644     36.0     35.0     5.0
# 34441     36.0    887.0     3.0
# 35914     36.0    306.0     4.0
# 36839     36.0    929.0     3.0
# 40381     36.0    191.0     4.0
# 41856     36.0     13.0     3.0
# 42548     36.0     57.0     4.0
# 42986     36.0    426.0     4.0
# 43795     36.0    436.0     5.0
# 47229     36.0    416.0     4.0
# 49133     36.0      4.0     5.0
# 51692     36.0    111.0     3.0
# 58039     36.0    377.0     3.0
# 60130     36.0    151.0     4.0
# 63014     36.0    339.0     5.0
# 63165     36.0    522.0     3.0
# 64011     36.0     77.0     4.0
# 70791     36.0     14.0     5.0
# 71913     36.0    113.0     3.0
# 73532     36.0     38.0     4.0
# 74310     36.0    325.0     4.0
#      book_id  content_rating
# 0          1    4.999850e-01
# 1          2    3.876922e-01
# 2          3    4.527195e-01
# 3          4    1.880443e+00
# 4          5    6.699982e-01
# ..       ...             ...
# 994      995    1.089901e-01
# 995      996    0.000000e+00
# 996      997    1.143346e-01
# 997      998    1.342989e-01
# 998      999   1.251488e-311
#
# [999 rows x 2 columns]
# content_done
#        book_id  collab_rating
# 1827     323.0       4.000000
# 1831     121.0       4.000000
# 3334     561.0       4.000000
# 3688      22.0       4.000000
# 6837     100.0       3.000000
# ...        ...            ...
# 95717    656.0       3.473050
# 95718    889.0       3.604414
# 95719    147.0       3.540538
# 95720     51.0       3.846789
# 95721    615.0       3.922523
#
# [714 rows x 2 columns]
# Collab_done
#      book_id  popularity_rating
# 2          3           3.938570
# 3          4           3.735043
# 4          5           4.170815
# 5          6           3.727862
# 7          8           3.867621
# ..       ...                ...
# 989      990           3.656186
# 994      995           3.735059
# 996      997           3.648905
# 997      998           3.719644
# 998      999           3.756854
#
# [713 rows x 2 columns]
# popularity _done
#        user_id  book_id    rating
# 1827      36.0    323.0  4.000000
# 1831      36.0    121.0  4.000000
# 3334      36.0    561.0  4.000000
# 3688      36.0     22.0  4.000000
# 6837      36.0    100.0  3.000000
# ...        ...      ...       ...
# 95717     36.0    656.0  3.473050
# 95718     36.0    889.0  3.604414
# 95719     36.0    147.0  3.540538
# 95720     36.0     51.0  3.846789
# 95721     36.0    615.0  3.922523
#
# [714 rows x 3 columns]
# 0.7683113225134216
#     hybrid_rating  user_id    rating
# 0          4.2668     36.0  5.000000
# 1          4.2043     36.0  4.000000
# 2          3.8701     36.0  5.000000
# 3          3.7500     36.0  5.000000
# 4          3.5870     36.0  5.000000
# ..            ...      ...       ...
# 499        2.6598     36.0  3.052938
# 500        2.6406     36.0  3.032805
# 501        2.6383     36.0  2.874736
# 502        2.6136     36.0  2.881689
# 503        2.5716     36.0  2.699233
#
# [504 rows x 3 columns]
#      book_id                               title                      genres  \
# 7         14                         Animal Farm                     [Drama]
# 10        22                    The Lovely Bones   [Psychological, Domestic]
# 1          4               To Kill a Mockingbird          [Self-Help, Drama]
# 16        28                   Lord of the Flies  [Psychological, Young-Age]
# 33        50             Where the Sidewalk Ends              [Poetry, Kids]
# ..       ...                                 ...                         ...
# 123      200            And Then There Were None             [Kids, Fiction]
# 112      174                           The Shack            [Drama, Fiction]
# 241      463  Dragonfly in Amber (Outlander, #2)          [History, Romance]
# 84       118                   The Joy Luck Club          [Classic, Fiction]
# 68        93                   The Secret Garden                      [Kids]
#
#      collaborative_rating  popularity_rating  content_rating hybrid_rating
# 7                5.000000           3.958220        3.417590        4.2668
# 10               4.000000           4.010628        5.000000        4.2043
# 1                5.000000           3.735043        1.880443        3.8701
# 16               5.000000           4.087252        0.575273        3.7500
# 33               5.000000           3.664829        0.605589        3.5870
# ..                    ...                ...             ...           ...
# 123              4.011901           3.796943        0.128703        3.1493
# 112              4.063596           3.733630        0.149738        3.1488
# 241              4.131222           3.706929        0.062819        3.1478
# 84               3.881814           3.937996        0.096819        3.1473
# 68               4.113964           3.679312        0.147218        3.1468
#
# [100 rows x 7 columns]
#        user_id  book_id  rating
# 156       38.0    786.0     3.0
# 2001      38.0     10.0     2.0
# 14988     38.0    959.0     4.0
# 15133     38.0    485.0     3.0
# 15541     38.0    935.0     2.0
# 16564     38.0    233.0     3.0
# 19364     38.0    213.0     4.0
# 39457     38.0    635.0     4.0
# 42049     38.0     66.0     3.0
# 43356     38.0     79.0     5.0
# 46570     38.0    706.0     3.0
# 48804     38.0     94.0     4.0
# 59235     38.0    413.0     3.0
# 59430     38.0     55.0     2.0
# 68661     38.0    121.0     3.0
# 70954     38.0    162.0     3.0
# 71901     38.0     18.0     4.0
# 72906     38.0    154.0     4.0
# 74369     38.0     85.0     3.0
# 74959     38.0    177.0     2.0
# 79908     38.0    934.0     3.0
#      book_id  content_rating
# 0          1    1.073890e-01
# 1          2    3.201900e-01
# 2          3    4.712850e-02
# 3          4    6.813949e-02
# 4          5    1.335152e-01
# ..       ...             ...
# 994      995    4.687058e-02
# 995      996    0.000000e+00
# 996      997    4.167835e-02
# 997      998    5.974362e-02
# 998      999   1.251448e-311
#
# [999 rows x 2 columns]
# content_done

# %%
h['hybrid_rating_round']= h['hybrid_rating']
h['hybrid_rating_round'] = h['hybrid_rating_round'].astype(float)

h['hybrid_rating_round']= h['hybrid_rating_round'].apply(np.floor)

#h.head(5)
rat = pd.read_csv('x_train.csv')
rat = rat[(rat['user_id'] == 116)][['user_id','book_id', 'rating']]

e = h.merge(rat,on = 'book_id')

#ratings.head(4)
e.head()
# Out:
#    book_id hybrid_rating  user_id_x  hybrid_rating_round  user_id_y  rating
# 0      162        4.2883        116                  4.0        116       5
# 1      213        4.1413        116                  4.0        116       5
# 2      599        4.1227        116                  4.0        116       5
# 3      297        4.1162        116                  4.0        116       5
# 4      398        4.0837        116                  4.0        116       4

# %%
rat = pd.read_csv('x_train.csv')
rat = rat[(rat['user_id'] == 1)][['user_id','book_id', 'rating']]
rat.head(4)
# Out:
#        user_id  book_id  rating
# 2449         1      268       3
# 65184        1       47       3

# %%
################# testing ###########################

# %%
def collaborative(ratings,user_id):

    reader = Reader()
    #ratings.head()

    new_ratings = ratings
    data = Dataset.load_from_df(new_ratings[['user_id', 'book_id', 'rating']], reader)
    #data.split(n_folds=2)

    ## Training the data ##
    svd = SVD()
    cross_validate(svd, data, measures=['RMSE', 'MAE'],cv=2)

    trainset = data.build_full_trainset()

    algo = SVD()
    algo.fit(trainset)

    #svd.train(trainset)
    ## Testing the data ##
    testset = trainset.build_anti_testset()
    predictions = algo.test(testset)
    count = 0
     
    for uid, iid, true_r, est, _ in predictions:
        if uid == user_id:
            count = count+1
            new_ratings.loc[len(new_ratings)+1]= [uid,iid,est]
            #print("book_sim " + str(new_ratings))

    cb = new_ratings[(new_ratings['user_id'] == user_id)][['book_id', 'rating']]
    cb.columns=['book_id', 'collab_rating']
    print(cb)
    print("Collab_done")
    return(cb)

# %%
y_test = pd.read_csv('x_test.csv')
cb = collaborative(y_test,3624)

# %%
# new = y_test
# new['hybrid']='1'
# new.head(4)
# Out:
#    user_id  book_id  rating hybrid
# 0     2699       63       2      1
# 1      249      353       5      1
# 2     2663       38       5      1
# 3     4067      343       4      1
